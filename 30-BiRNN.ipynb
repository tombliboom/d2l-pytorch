# %% [markdown]
# # 双向循环神经网络

# %% [markdown]
# ## 1. 双向模型
# ![image.png](attachment:b79416ff-124f-46bc-b539-bf556a4f1f66.png)

# %% [markdown]
# + 定义
# ![image.png](attachment:5634e009-6887-48c3-a61a-542bf21e98ab.png)
#
# + 模型的计算代价及其应用
# ![image.png](attachment:ede3314f-6b8e-49f1-acce-b50a55c0e324.png)
